# %% [markdown]
# # Spacy

# %% [markdown]
# ## Load Module

# %%
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ## Tokenize

# %%
doc = nlp(u"Apple is looking at buying a U.K. startup for $1 billion")
for token in doc:
  print(token.text)
# Out:
# Apple
# is
# looking
# at
# buying
# a
# U.K.
# startup
# for
# $
# 1
# billion

# %% [markdown]
# ## Part of Speech & properties

# %%
for word in doc:  
  print(word.text, word.pos_, sep = '\t')
# Out:
# Apple	PROPN
# is	AUX
# looking	VERB
# at	ADP
# buying	VERB
# a	DET
# U.K.	PROPN
# startup	NOUN
# for	ADP
# $	SYM
# 1	NUM
# billion	NUM

# %% [markdown]
# ## Display Despondencies

# %%
doc = nlp(u"I want an iPad, Laptop, and a dog.")
displacy.serve(doc, style = "dep")
# Out:
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# ## Lemmatizing

# %%
sentence = "The striped bats are hanging on their feet for best"

# Parse the sentence using the loaded 'en' model object `nlp`
doc = nlp(sentence)

# Extract the lemma for each token and join
" ".join([token.lemma_ for token in doc])
#> 'the strip bat be hang on -PRON- foot for good'
# Out:
# 'the stripe bat be hang on -PRON- foot for good'

# %% [markdown]
# ## Stop Words

# %%
from spacy.lang.en.stop_words import STOP_WORDS

print(STOP_WORDS)
# Out:
# {'noone', 'i', 'perhaps', "'ll", 'whose', 'meanwhile', 'whereafter', 'front', 'am', 'nevertheless', 'must', 'whenever', 'whoever', 'become', 'almost', 'yourself', 'became', 'throughout', 'have', 'why', 'also', 'during', 'up', 'part', 'as', 'are', 'full', 'you', '’d', 'our', 'somewhere', 'but', 'hereupon', 'quite', 'wherever', 'myself', 'becomes', 'off', 'amongst', 'upon', 'keep', 'few', 'others', 'very', 'seem', 'be', 'yours', 'done', 'could', 'with', 'anyone', 'does', 'although', 'she', 'this', 'three', 'whereas', 'much', 'get', 'more', 'nine', 'where', 'whole', 'to', 'fifty', 'give', 'than', 'might', 'himself', 'some', 'from', 'using', 'and', 'same', 'herself', 'however', 'unless', 'back', 'along', 'hers', '’re', 'had', 'did', 'always', 'because', 'itself', 'except', 'thus', 'do', 'your', "'ve", 'if', 'per', 'yourselves', 'formerly', 'put', '’m', 'hundred', 'two', 'again', 'thereby', 'seems', 'n’t', "'s", 'becoming', 'at', 'after', '’ll', 'several', 'an', 'via', "'d", 'between', 'therefore', 'when', 'a', 'both', 'it', 'whatever', 'together', 'go', 'nothing', 'eight', 'many', 'already', 'been', 'should', 'above', 'else', 'four', 'we', 'they', 'whereby', 'until', 'everyone', 'alone', 'no', 'by', 'never', 'indeed', 'around', 'whither', 'side', 'behind', 'every', 'still', 'their', 'only', 'rather', 'thereupon', 'me', 'fifteen', 'beforehand', 'six', 'across', 're', 'so', 'whether', 'whom', 'enough', 'hereafter', 'beside', 'what', 'before', 'that', 'twelve', 'empty', '’ve', 'below', 'among', 'sometimes', 'which', 'make', 'call', 'onto', 'yet', 'something', 'take', 'otherwise', 'sixty', 'first', 'see', 'everywhere', '‘m', 'sometime', 'last', 'neither', 'own', 'how', 'one', 'either', 'therein', 'him', 'the', 'move', 'each', 'mostly', '’s', 'once', 'too', 'nor', 'down', '‘ll', 'then', 'used', 'nobody', 'show', 'elsewhere', 'into', 'twenty', 'former', 'next', 'various', 'thereafter', 'is', 'everything', 'least', 'its', 'another', 'seeming', 'often', 'whereupon', 'none', 'most', 'anything', 'ten', 'themselves', 'wherein', 'though', 'would', 'n‘t', 'her', 'there', 'top', 'regarding', 'well', 'being', 'due', 'hence', 'someone', 'within', 'over', 'anyway', 'of', 'here', 'may', 'say', 'was', 'made', 'his', 'ours', 'not', "n't", 'nowhere', 'ourselves', '‘re', 'somehow', 'moreover', 'were', 'less', 'under', 'even', 'anywhere', 'has', 'cannot', 'in', 'namely', 'ever', 'on', 'while', 'without', 'amount', 'or', 'ca', 'thru', 'whence', 'hereby', 'really', 'afterwards', 'toward', 'can', 'any', "'m", 'these', 'latterly', 'for', '‘s', 'serious', 'my', 'other', 'will', 'herein', 'against', 'those', 'them', 'third', 'such', 'eleven', 'all', 'doing', 'about', 'now', 'us', 'who', 'towards', 'beyond', 'since', 'anyhow', 'please', 'he', 'seemed', 'thence', "'re", 'out', 'besides', 'through', 'just', 'mine', 'five', '‘ve', '‘d', 'bottom', 'further', 'name', 'latter', 'forty'}
